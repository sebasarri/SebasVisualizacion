# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
x= 16
y= 8

if x<y:
    print('{} es menor que{}'.format (x,y))
else: 
    print('{} es menor que {}'.format (y,x))
# Out:
# 8 es menor que 16

# %%
my_list= [True, 6<5, 1==3, None is None]
my_list
# Out:
# [True, False, False, True]

# %%
for i in my_list:
    print('{}\t {}'.format(i,type(i)))
# Out:
# True	 <class 'bool'>
# False	 <class 'bool'>
# False	 <class 'bool'>
# True	 <class 'bool'>

# %%
for i in my_list:
    print(i,'\t', type(i))
# Out:
# True 	 <class 'bool'>
# False 	 <class 'bool'>
# False 	 <class 'bool'>
# True 	 <class 'bool'>

# %%
x= None
type(x)
# Out:
# NoneType

# %%
none_list= [None]*5
none_list
# Out:
# [None, None, None, None, None]

# %%
len(none_list)
# Out:
# 5

# %%
una_lista = ['pos0','first', 'second', 'third', 'fourth', 'fifth']
una_lista
# Out:
# ['pos0', 'first', 'second', 'third', 'fourth', 'fifth']

# %%
len(una_lista)
# Out:
# 6

# %%
una_lista[2]
# Out:
# 'second'

# %%
una_lista[3]
# Out:
# 'third'

# %%
una_lista[0:3]
# Out:
# ['pos0', 'first', 'second']

# %%
una_lista[0:4]
# Out:
# ['pos0', 'first', 'second', 'third']

# %%
una_lista
# Out:
# ['pos0', 'first', 'second', 'third', 'fourth', 'fifth']

# %%
una_lista[-2:]
# Out:
# ['fourth', 'fifth']

# %%
num_arrray= np. array[0, 1, 2, 3, 4, 5, 6, 7]
num_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-20b9aea521ec> in <module>
# ----> 1 num_arrray= np. array[0, 1, 2, 3, 4, 5, 6, 7]
#       2 num_array
#
# NameError: name 'np' is not defined

# %%
import pandas as pd
data_set= 'datasets/Cartwheeldata.csv'
df = pd.read_csv(data_set)

# %%
df
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.head(13)
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0    1   56      F            1       Y             1   62.00      61.0
# 1    2   26      F            1       Y             1   62.00      60.0
# 2    3   33      F            1       Y             1   66.00      64.0
# 3    4   39      F            1       N             0   64.00      63.0
# 4    5   27      M            2       N             0   73.00      75.0
# 5    6   24      M            2       N             0   75.00      71.0
# 6    7   28      M            2       N             0   75.00      76.0
# 7    8   22      F            1       N             0   65.00      62.0
# 8    9   29      M            2       Y             1   74.00      73.0
# 9   10   33      F            1       Y             1   63.00      60.0
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
una_lista.sort()
una_lista
# Out:
# ['fifth', 'first', 'fourth', 'pos0', 'second', 'third']

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
index_list=list(df.columns)

# %%
index_list.sort()
index_list
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %%
for i in df.columns:
    print(i)
# Out:
# ID
# Age
# Gender
# GenderGroup
# Glasses
# GlassesGroup
# Height
# Wingspan
# CWDistance
# Complete
# CompleteGroup
# Score

# %%
df.loc['Height']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Height'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-936cb7852b3d> in <module>
# ----> 1 df.loc['Height']
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
# ...

# %%
df['Height']
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64

# %%
df[['Height']]
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00

# %%
x = df['Height']
print(x)
print(type(x))
# Out:
# 0     62.00
# 1     62.00
# 2     66.00
# 3     64.00
# 4     73.00
# 5     75.00
# 6     75.00
# 7     65.00
# 8     74.00
# 9     63.00
# 10    69.50
# 11    62.75
# 12    65.00
# 13    61.50
# 14    73.00
# 15    71.00
# 16    61.50
# 17    66.00
# 18    70.00
# 19    68.00
# 20    69.00
# 21    71.00
# 22    70.00
# 23    69.00
# 24    65.00
# Name: Height, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
y = df[['Height']]
print(y)
print(type(y))
# Out:
#     Height
# 0    62.00
# 1    62.00
# 2    66.00
# 3    64.00
# 4    73.00
# 5    75.00
# 6    75.00
# 7    65.00
# 8    74.00
# 9    63.00
# 10   69.50
# 11   62.75
# 12   65.00
# 13   61.50
# 14   73.00
# 15   71.00
# 16   61.50
# 17   66.00
# 18   70.00
# 19   68.00
# 20   69.00
# 21   71.00
# 22   70.00
# 23   69.00
# 24   65.00
# <class 'pandas.core.frame.DataFrame'>

# %%
df[['Height','Gender']]
# Out:
#     Height Gender
# 0    62.00      F
# 1    62.00      F
# 2    66.00      F
# 3    64.00      F
# 4    73.00      M
# 5    75.00      M
# 6    75.00      M
# 7    65.00      F
# 8    74.00      M
# 9    63.00      F
# 10   69.50      M
# 11   62.75      F
# 12   65.00      F
# 13   61.50      F
# 14   73.00      M
# 15   71.00      M
# 16   61.50      F
# 17   66.00      M
# 18   70.00      M
# 19   68.00      F
# 20   69.00      M
# 21   71.00      M
# 22   70.00      M
# 23   69.00      M
# 24   65.00      F

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
df.loc[1:4] #rowstart : rowend, columns_start:columns_end
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.loc[:,'Age':'GenderGroup']
# Out:
#     Age Gender  GenderGroup
# 0    56      F            1
# 1    26      F            1
# 2    33      F            1
# 3    39      F            1
# 4    27      M            2
# 5    24      M            2
# 6    28      M            2
# 7    22      F            1
# 8    29      M            2
# 9    33      F            1
# 10   30      M            2
# 11   28      F            1
# 12   25      F            1
# 13   23      F            1
# 14   31      M            2
# 15   26      M            2
# 16   26      F            1
# 17   27      M            2
# 18   23      M            2
# 19   24      F            1
# 20   23      M            2
# 21   29      M            2
# 22   25      M            2
# 23   26      M            2
# 24   23      F            1

# %%
df.loc[:3, 'GenderGroup':]
# Out:
#    GenderGroup Glasses  GlassesGroup  Height  Wingspan  CWDistance Complete  \
# 0            1       Y             1    62.0      61.0          79        Y
# 1            1       Y             1    62.0      60.0          70        Y
# 2            1       Y             1    66.0      64.0          85        Y
# 3            1       N             0    64.0      63.0          87        Y
#
#    CompleteGroup  Score
# 0              1      7
# 1              1      8
# 2              1      7
# 3              1     10

# %%
df.iloc[:3, 1:4]
# Out:
#    Age Gender  GenderGroup
# 0   56      F            1
# 1   26      F            1
# 2   33      F            1

# %%
df.groupby(['Gender','GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64
